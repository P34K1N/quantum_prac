# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
with open('res/acc_26_0.1.txt') as f:
    lines = f.read().splitlines()
d = [float(i) for i in lines]
print(d)
# Out:
# [0.0956408, 0.0916277, 0.10642, 0.0823553, 0.0812449, 0.104483, 0.101487, 0.0836682, 0.112225, 0.133354, 0.0861502, 0.0936275, 0.0829591, 0.122424, 0.103723, 0.105612, 0.111977, 0.0913648, 0.102589, 0.0913737, 0.106733, 0.0876863, 0.0797494, 0.102403, 0.0815366, 0.0833455, 0.087902, 0.0956219, 0.105202, 0.084297, 0.0812131, 0.102563, 0.109353, 0.102592, 0.098205, 0.104453, 0.102218, 0.119038, 0.0745697, 0.104176, 0.115935, 0.105138, 0.0910708, 0.0870859, 0.0710592, 0.09733, 0.101552, 0.0845599, 0.085202, 0.101271, 0.106803, 0.105084, 0.0849738, 0.0862623, 0.114105, 0.107353, 0.0887353, 0.110526, 0.0580457, 0.0702118]

# %%
# An "interface" to matplotlib.axes.Axes.hist() method
n, bins, patches = plt.hist(x=d, bins=10, color='#0504aa',
                            alpha=0.7, rwidth=0.85)
plt.grid(axis='y', alpha=0.75)
plt.xlabel('1 - F')
plt.ylabel('Freq')
plt.title('n = 26, e = 0.1')
maxfreq = n.max()
# Set a clean upper y-axis limit.
plt.ylim(ymax=np.ceil(maxfreq / 10) * 10 if maxfreq % 10 else maxfreq + 10)
# Out:
# (0.0, 20.0)
